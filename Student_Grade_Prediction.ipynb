# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\KIIT0001\Downloads\student-por (1).csv")
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        4   0  11  11
# 1    ...      5        3      3     1     1      3        2   9  11  11
# 2    ...      4        3      2     2     3      3        6  12  13  12
# 3    ...      3        2      2     1     1      5        0  14  14  14
# 4    ...      4        3      2     1     2      5        0  11  13  13
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [649 rows x 33 columns]

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X = df.drop('G3', axis=1)
y = df['G3']

X=pd.get_dummies(X,drop_first=True)
X_train,X_test,y_train, y_test=train_test_split(X,y,test_size=0.2)

# %%
X.head()
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         0       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  ...  guardian_mother  guardian_other  schoolsup_yes  famsup_yes  \
# 0     1  ...             True           False           True       False
# 1     1  ...            False           False          False        True
# 2     2  ...             True           False           True       False
# 3     1  ...             True           False          False        True
# 4     1  ...            False           False          False        True
#
#    paid_yes  activities_yes  nursery_yes  higher_yes  internet_yes  \
# 0     False           False         True        True         False
# 1     False           False        False        True          True
# 2     False           False         True        True          True
# 3     False            True         True        True          True
# 4     False           False         True        True         False
#
#    romantic_yes
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
#
# [5 rows x 41 columns]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=lr.predict(X_test)
predictions
# Out:
# array([11.87796703, 16.99936214, 15.38154092, 11.81927658, 11.80921091,
#        13.83014723, 10.51340489, 13.22121421,  9.15443376, 15.86505428,
#        11.00967433,  9.74746176,  8.19332006,  8.34395248, 10.76891017,
#         9.60800938, 16.47795344,  9.898353  ,  8.76804605, 10.66930754,
#        13.27959558, 11.54563333, 15.24603812,  8.24551139, 14.19900185,
#        12.45237994, 10.80816999, 11.5811817 , 12.79080227, 13.80329189,
#        14.88237324,  8.47066391,  9.11882063,  7.82168171,  6.88388306,
#        10.71736507, 11.40404894, 18.57918732, 10.6572075 , 10.34244527,
#        10.12459292, 11.01269155, 11.38148122, 14.39130432, 17.92785162,
#        12.61188674, 12.37069821, 15.25000229,  9.91917621, 13.43656066,
#        12.98296267, 13.92345715, 11.23304087, 16.36136899, 13.15024319,
#        11.50541558,  7.0217647 , 12.96227591, 11.26334263, 14.6476551 ,
#        11.04154915, 11.32472261, 15.64364906,  9.80679519, 15.71667465,
#        11.18314241, 12.29979407, 15.03994628, 11.30899328, 10.0439786 ,
#         9.53849692,  8.99336775, 11.40147941,  8.64705676, 11.32170612,
#        11.26538166, 10.15694766, 16.49583599, 12.79500002, 12.54708203,
#         5.41764664, 11.33405012, 17.8269437 , 10.49564324, 14.34917036,
#        11.74224342, 18.53614149, 13.09097562, 13.06361757, 14.00420132,
#        16.58033302, 13.0542086 , 18.85665259, 11.3020088 ,  9.11162759,
#        14.51353483, 13.64692599,  8.54141204,  9.63066842, 18.58372388,
#        16.32274454, 10.77831319, 10.51858066, 14.46725373, 11.36158757,
#        11.10955742, 10.36368159, 16.47920164, 12.57448398,  8.71336494,
#        17.70352634, 13.18980481, 14.05786193, 13.96434883, 15.07230875,
#         9.22604311,  6.65212583, 18.4191636 ,  9.06106527,  8.96778396,
#        13.66708489,  9.46214969,  0.24329519, 10.20411323, 11.05951142,
#         9.01864839, 11.94590099, 12.42694687, 13.73364784, 16.05965385])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,predictions)
# Out:
# 0.8264943452765541

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, predictions)
# Out:
# 1.996280090357735

# %%
from sklearn.metrics import root_mean_squared_error
root_mean_squared_error(y_test,predictions)
# Out:
# 1.4128977635900395

# %%
from matplotlib import pyplot as plt

# %%
from matplotlib import pyplot as plt

plt.scatter(y_test, predictions)

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    'r--'
)

plt.xlabel("Actual Grade")
plt.ylabel("Predicted Grade")
plt.title("Actual vs Predicted Grades")

plt.show()
